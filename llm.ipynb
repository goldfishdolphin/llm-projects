# %%
from openai import OpenAI 
import os

# %%
with open("nebius_api_key", "r") as file:
    nebius_api_key = file.read().strip()

os.environ["NEBIUS_API_KEY"] = nebius_api_key

with open("openai_api_key", "r") as file:
    openai_api_key = file.read().strip()

os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
client = OpenAI(
    base_url="https://api.studio.nebius.ai/v1/",
    api_key=os.environ.get("NEBIUS_API_KEY"),
)   
model = "openai/gpt-oss-120b"
messages = [
    {"role": "system", "content": "You are a magician."},
    {"role": "user", "content": "Hello, who won the world series in 2020?"}
]
completion = client.chat.completions.create(
    model=model,
    messages=messages
)

# %%
# !pwd
# Out:
# /Users/naureenimran/projects/llm-projects

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-7c1d9e6ceb094d1d87df32708fe2c4a8', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The 2020 World Series was won by the **Los Angeles\u202fDodgers**. They defeated the Tampa Bay\u202fRays in six games to claim the championship.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[], reasoning_content='The user asks: "Hello, who won the world series in 2020?" This is straightforward factual question. The answer: Los Angeles Dodgers won the World Series in 2020, defeating the Tampa Bay Rays. Provide that.'), stop_reason=None, token_ids=None)], created=1756625843, model='openai/gpt-oss-120b', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=91, prompt_tokens=93, total_tokens=184, completion_tokens_details=None, prompt_tokens_details=None), prompt_logprobs=None, prompt_token_ids=None, kv_transfer_params=None)

# %%
completion.choices[0].message.content
# Out:
# 'Ah, gather ’round, dear seeker of baseball lore, and let the veil of time part before your very eyes! 🌟✨\n\nIn the enchanted year of 2020, when the world was still dancing to a strange new rhythm, the **Los\u202fAngeles Dodgers** conjured a spell of triumph and seized the **World Series crown**. They bested the mighty **Tampa Bay Rays** in a dramatic six‑game showdown, bringing the trophy home to the glittering streets of Los\u202fAngeles.\n\nSo, with a flick of a wand and a swing of a bat, the Dodgers etched their name into the annals of baseball magic! ⚾🪄'

# %%
completion.model
# Out:
# 'openai/gpt-oss-120b'

# %%
# !gdown 1OW4MjT6A-5gUpyAi0_NyH94tCoNKGu8p
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OW4MjT6A-5gUpyAi0_NyH94tCoNKGu8p
# To: /Users/naureenimran/projects/llm-projects/map000.png
# 100%|████████████████████████████████████████| 190k/190k [00:00<00:00, 6.93MB/s]

# %%
# !pip install gdown
# Out:
# DEPRECATION: Loading egg at /opt/anaconda3/lib/python3.11/site-packages/plot_model-0.20-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/lib/python3.11/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/lib/python3.11/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

img_path = 'map000.png'
if os.path.exists(img_path):
	img = mpimg.imread(img_path)
	plt.figure(figsize=(10, 10))
	imgplot = plt.imshow(img)
	plt.axis('off')
	plt.show()
else:
	print(f"File '{img_path}' not found. Please check the file path or download the image.")

# %%
from openai import OpenAI
import base64

IMAGE_PATH = 'map000.png'
model = 'gpt-4o-mini'
client = OpenAI()

# Open the image file and encode it as a base64 string
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

base64_image = encode_image(IMAGE_PATH)

# %%
base64_image
# Out:
# '...'

# %%
journey_start = "Sunweave"
journey_end = "Shadowglade"

geography_prompt = f"""You are given a map of a fantasy realm.
It is divided into a number of regions with the name of the region indicated inside of it.
Your task is to describe potential journey from {journey_start} to {journey_end}.
Make sure that consecutive regions in the journey plan are really adjacent.
Only output a list of regions you'd pass on this journey as a list in exactly the following format:

JOURNEY:

{journey_start}
Region_1
...
Region_n
{journey_end}

YOUR RESPONSE:"""

completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are an expert pathfinder"},
        {"role": "user", "content": [
            {"type": "text", "text": geography_prompt},
            {"type": "image_url", "image_url": {
                "url": f"data:image/png;base64,{base64_image}"}
            }
        ]}
    ]
)

print(completion.choices[0].message.content)
# Out:
# JOURNEY:
#
# Sunweave
# Silvermeadow
# Emberkeep
# Crystalpeak
# Shadowglade

# %%
client = OpenAI(
    base_url="https://api.studio.nebius.ai/v1/",
    api_key=os.environ.get("NEBIUS_API_KEY"),
)

model = "Qwen/Qwen2-VL-72B-Instruct"

completion = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are an expert pathfinder"},
        {"role": "user", "content": [
            {"type": "text", "text": geography_prompt},
            {"type": "image_url", "image_url": {
                "url": f"data:image/png;base64,{base64_image}"}
            }
        ]}
    ]
)

print(completion.choices[0].message.content)
# Out:
# JOURNEY:
#
# Sunweave
# Wyrmrest
# Silvermeadow
# Shadowglade
